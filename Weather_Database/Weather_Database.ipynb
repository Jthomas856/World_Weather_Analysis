# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_weather_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | ulladulla
# Processing Record 3 of Set 1 | arenapolis
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | gumdag
# Processing Record 7 of Set 1 | abu zabad
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | klaeng
# Processing Record 10 of Set 1 | hegang
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | gamba
# Processing Record 15 of Set 1 | leningradskiy
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | umm lajj
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | iwanai
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | varnavino
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | saint-pierre
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | meybod
# Processing Record 39 of Set 1 | kirakira
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | fernandina beach
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | wuwei
# Processing Record 1 of Set 2 | skibbereen
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | madison heights
# Processing Record 4 of Set 2 | pinega
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | salalah
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | grindavik
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | port hardy
# Processing Record 12 of Set 2 | tessalit
# Processing Record 13 of Set 2 | cartagena
# Processing Record 14 of Set 2 | yar-sale
# Processing Record 15 of Set 2 | cangzhou
# Processing Record 16 of Set 2 | garrel
# Processing Record 17 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 2 | evensk
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | banda aceh
# Processing Record 21 of Set 2 | jiuquan
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | gidole
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | burnie
# Processing Record 28 of Set 2 | namie
# Processing Record 29 of Set 2 | yumen
# Processing Record 30 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | paamiut
# Processing Record 33 of Set 2 | pangnirtung
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | kaeo
# Processing Record 36 of Set 2 | nanga eboko
# Processing Record 37 of Set 2 | romans-sur-isere
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | constitucion
# Processing Record 40 of Set 2 | seoul
# Processing Record 41 of Set 2 | erenhot
# Processing Record 42 of Set 2 | gonen
# Processing Record 43 of Set 2 | dayong
# Processing Record 44 of Set 2 | broome
# Processing Record 45 of Set 2 | great bend
# Processing Record 46 of Set 2 | namwala
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | vostok
# Processing Record 49 of Set 2 | santa marta
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | shiraz
# Processing Record 3 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | cabedelo
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | henties bay
# Processing Record 9 of Set 3 | korla
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | chissamba
# Processing Record 12 of Set 3 | sola
# Processing Record 13 of Set 3 | brownwood
# Processing Record 14 of Set 3 | port shepstone
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | srednekolymsk
# Processing Record 17 of Set 3 | skjold
# Processing Record 18 of Set 3 | lompoc
# Processing Record 19 of Set 3 | viedma
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | abha
# Processing Record 23 of Set 3 | college
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | venado tuerto
# Processing Record 26 of Set 3 | la ronge
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 3 | urumqi
# Processing Record 30 of Set 3 | mosquera
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | lasa
# Processing Record 33 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | tobol
# Processing Record 36 of Set 3 | champerico
# Processing Record 37 of Set 3 | dunedin
# Processing Record 38 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 3 | polyarnyye zori
# Processing Record 40 of Set 3 | sozimskiy
# Processing Record 41 of Set 3 | hrusovany nad jevisovkou
# Processing Record 42 of Set 3 | jijiga
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | rudsar
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | porto belo
# Processing Record 49 of Set 3 | keokuk
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | calama
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | souillac
# Processing Record 5 of Set 4 | faanui
# Processing Record 6 of Set 4 | kilrush
# Processing Record 7 of Set 4 | chimbote
# Processing Record 8 of Set 4 | deputatskiy
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | regina
# Processing Record 12 of Set 4 | aykhal
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | nenjiang
# Processing Record 15 of Set 4 | iberia
# Processing Record 16 of Set 4 | porto novo
# Processing Record 17 of Set 4 | hovd
# Processing Record 18 of Set 4 | vila velha
# Processing Record 19 of Set 4 | mpika
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | mao
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | tazovskiy
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | acarau
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | zhangye
# Processing Record 30 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 4 | dabeiba
# Processing Record 33 of Set 4 | abalak
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | bilibino
# Processing Record 36 of Set 4 | alta floresta
# Processing Record 37 of Set 4 | xining
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | harlingen
# Processing Record 40 of Set 4 | meadow lake
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | olafsvik
# Processing Record 43 of Set 4 | miri
# Processing Record 44 of Set 4 | aklavik
# Processing Record 45 of Set 4 | hofn
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 4 | rio grande
# Processing Record 49 of Set 4 | ulaanbaatar
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | murakami
# Processing Record 2 of Set 5 | bentiu
# Processing Record 3 of Set 5 | mandalgovi
# Processing Record 4 of Set 5 | snezhnogorsk
# Processing Record 5 of Set 5 | lukovetskiy
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | kupang
# Processing Record 8 of Set 5 | half moon bay
# Processing Record 9 of Set 5 | eastlake
# Processing Record 10 of Set 5 | yermakovskoye
# Processing Record 11 of Set 5 | airai
# Processing Record 12 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 5 | zakamensk
# Processing Record 14 of Set 5 | palana
# Processing Record 15 of Set 5 | yerbogachen
# Processing Record 16 of Set 5 | tilichiki
# Processing Record 17 of Set 5 | inta
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | ekibastuz
# Processing Record 20 of Set 5 | buraydah
# Processing Record 21 of Set 5 | mehamn
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | pevek
# Processing Record 24 of Set 5 | morondava
# Processing Record 25 of Set 5 | butaritari
# Processing Record 26 of Set 5 | poum
# Processing Record 27 of Set 5 | tuatapere
# Processing Record 28 of Set 5 | kerema
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | azua
# Processing Record 32 of Set 5 | kontagora
# Processing Record 33 of Set 5 | myitkyina
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | pizarro
# Processing Record 36 of Set 5 | castro
# Processing Record 37 of Set 5 | verkhnevilyuysk
# Processing Record 38 of Set 5 | paliyad
# Processing Record 39 of Set 5 | jilib
# Processing Record 40 of Set 5 | avera
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | dois corregos
# Processing Record 43 of Set 5 | morwell
# Processing Record 44 of Set 5 | grand-santi
# Processing Record 45 of Set 5 | teguise
# Processing Record 46 of Set 5 | port moresby
# Processing Record 47 of Set 5 | bocaiuva
# Processing Record 48 of Set 5 | manado
# Processing Record 49 of Set 5 | kathu
# Processing Record 50 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | camana
# Processing Record 3 of Set 6 | vangaindrano
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | gat
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | alyangula
# Processing Record 8 of Set 6 | sibolga
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | amahai
# Processing Record 11 of Set 6 | doka
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | belaya gora
# Processing Record 14 of Set 6 | jieshi
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | bako
# Processing Record 17 of Set 6 | saldanha
# Processing Record 18 of Set 6 | maragogi
# Processing Record 19 of Set 6 | guarapari
# Processing Record 20 of Set 6 | te horo
# Processing Record 21 of Set 6 | port hedland
# Processing Record 22 of Set 6 | chokurdakh
# Processing Record 23 of Set 6 | chiguayante
# Processing Record 24 of Set 6 | biloela
# Processing Record 25 of Set 6 | rio gallegos
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | puerto quijarro
# Processing Record 28 of Set 6 | khovu-aksy
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | mlowo
# Processing Record 31 of Set 6 | koumac
# Processing Record 32 of Set 6 | sao gabriel da cachoeira
# Processing Record 33 of Set 6 | truro
# Processing Record 34 of Set 6 | schoneiche
# Processing Record 35 of Set 6 | sao felix do xingu
# Processing Record 36 of Set 6 | nikolskoye
# Processing Record 37 of Set 6 | ormara
# Processing Record 38 of Set 6 | portland
# Processing Record 39 of Set 6 | naryan-mar
# Processing Record 40 of Set 6 | shubarshi
# Processing Record 41 of Set 6 | tautira
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | saint-joseph
# Processing Record 44 of Set 6 | conceicao do araguaia
# Processing Record 45 of Set 6 | liverpool
# Processing Record 46 of Set 6 | hearst
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | dakoro
# Processing Record 50 of Set 6 | longyearbyen
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 2 of Set 7 | buckeye
# Processing Record 3 of Set 7 | corrales
# Processing Record 4 of Set 7 | inuvik
# Processing Record 5 of Set 7 | touho
# Processing Record 6 of Set 7 | madingou
# Processing Record 7 of Set 7 | turukhansk
# Processing Record 8 of Set 7 | monrovia
# Processing Record 9 of Set 7 | bhasawar
# Processing Record 10 of Set 7 | sakaiminato
# Processing Record 11 of Set 7 | yaan
# Processing Record 12 of Set 7 | jerome
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | terrace
# Processing Record 15 of Set 7 | sambava
# Processing Record 16 of Set 7 | goya
# Processing Record 17 of Set 7 | padang
# Processing Record 18 of Set 7 | maniitsoq
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | biak
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | sioux lookout
# Processing Record 23 of Set 7 | manokwari
# Processing Record 24 of Set 7 | nelson bay
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | sechura
# Processing Record 27 of Set 7 | newcastle
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | makat
# Processing Record 30 of Set 7 | sarangani
# Processing Record 31 of Set 7 | colac
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 7 | nizwa
# Processing Record 35 of Set 7 | bachaquero
# Processing Record 36 of Set 7 | sao joao da barra
# Processing Record 37 of Set 7 | yarada
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | suntar
# Processing Record 41 of Set 7 | victor harbor
# Processing Record 42 of Set 7 | faya
# Processing Record 43 of Set 7 | mocuba
# Processing Record 44 of Set 7 | quatre cocos
# Processing Record 45 of Set 7 | amalapuram
# Processing Record 46 of Set 7 | linxia
# Processing Record 47 of Set 7 | fraserburgh
# Processing Record 48 of Set 7 | barabinsk
# Processing Record 49 of Set 7 | moa
# Processing Record 50 of Set 7 | carauari
# Processing Record 1 of Set 8 | mahibadhoo
# Processing Record 2 of Set 8 | concordia
# Processing Record 3 of Set 8 | santiago del estero
# Processing Record 4 of Set 8 | dingle
# Processing Record 5 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 8 | yongchang
# Processing Record 7 of Set 8 | coahuayana
# Processing Record 8 of Set 8 | voznesenskoye
# Processing Record 9 of Set 8 | chom bung
# City not found. Skipping...
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | panambi
# Processing Record 12 of Set 8 | eyl
# Processing Record 13 of Set 8 | karakulino
# Processing Record 14 of Set 8 | flin flon
# Processing Record 15 of Set 8 | la paz
# Processing Record 16 of Set 8 | bratsk
# Processing Record 17 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 18 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 8 | nizhniy ufaley
# Processing Record 20 of Set 8 | chernaya kholunitsa
# Processing Record 21 of Set 8 | luklukan
# Processing Record 22 of Set 8 | aswan
# Processing Record 23 of Set 8 | strezhevoy
# Processing Record 24 of Set 8 | porto franco
# Processing Record 25 of Set 8 | barinitas
# Processing Record 26 of Set 8 | majene
# Processing Record 27 of Set 8 | vuktyl
# Processing Record 28 of Set 8 | tanabe
# Processing Record 29 of Set 8 | andijon
# Processing Record 30 of Set 8 | matara
# Processing Record 31 of Set 8 | punta alta
# Processing Record 32 of Set 8 | mudgee
# Processing Record 33 of Set 8 | isabela
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | nogliki
# Processing Record 36 of Set 8 | puerto maldonado
# Processing Record 37 of Set 8 | laguna
# Processing Record 38 of Set 8 | la cruz
# Processing Record 39 of Set 8 | callaguip
# Processing Record 40 of Set 8 | balgazyn
# Processing Record 41 of Set 8 | mbandaka
# Processing Record 42 of Set 8 | saint anthony
# Processing Record 43 of Set 8 | tafresh
# Processing Record 44 of Set 8 | satipo
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | mattru
# Processing Record 47 of Set 8 | puerto leguizamo
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | martyush
# Processing Record 1 of Set 9 | kemijarvi
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | leticia
# Processing Record 4 of Set 9 | sitka
# Processing Record 5 of Set 9 | komsomolskiy
# Processing Record 6 of Set 9 | dali
# Processing Record 7 of Set 9 | paita
# Processing Record 8 of Set 9 | shizunai
# Processing Record 9 of Set 9 | voi
# Processing Record 10 of Set 9 | saint-francois
# Processing Record 11 of Set 9 | troitskoye
# Processing Record 12 of Set 9 | lithakia
# Processing Record 13 of Set 9 | labuhan
# Processing Record 14 of Set 9 | urtaaul
# City not found. Skipping...
# Processing Record 15 of Set 9 | karla
# Processing Record 16 of Set 9 | farah
# Processing Record 17 of Set 9 | celestun
# Processing Record 18 of Set 9 | weinan
# Processing Record 19 of Set 9 | mamou
# Processing Record 20 of Set 9 | biltine
# Processing Record 21 of Set 9 | kandry
# Processing Record 22 of Set 9 | arlit
# Processing Record 23 of Set 9 | carmarthen
# Processing Record 24 of Set 9 | griffith
# Processing Record 25 of Set 9 | candelaria
# Processing Record 26 of Set 9 | key west
# Processing Record 27 of Set 9 | chernyshevskiy
# Processing Record 28 of Set 9 | lyantonde
# Processing Record 29 of Set 9 | slave lake
# Processing Record 30 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 9 | abancay
# Processing Record 33 of Set 9 | kampong thum
# Processing Record 34 of Set 9 | waddan
# Processing Record 35 of Set 9 | bac lieu
# Processing Record 36 of Set 9 | richards bay
# Processing Record 37 of Set 9 | esso
# Processing Record 38 of Set 9 | jumla
# Processing Record 39 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 9 | kozhva
# Processing Record 41 of Set 9 | fatezh
# Processing Record 42 of Set 9 | miles city
# Processing Record 43 of Set 9 | ulagan
# Processing Record 44 of Set 9 | corvallis
# Processing Record 45 of Set 9 | itarema
# Processing Record 46 of Set 9 | lagos
# Processing Record 47 of Set 9 | anniston
# Processing Record 48 of Set 9 | teya
# Processing Record 49 of Set 9 | tammisaari
# Processing Record 50 of Set 9 | buala
# Processing Record 1 of Set 10 | hazorasp
# Processing Record 2 of Set 10 | guymon
# Processing Record 3 of Set 10 | tres picos
# Processing Record 4 of Set 10 | reconquista
# Processing Record 5 of Set 10 | vao
# Processing Record 6 of Set 10 | san juan
# Processing Record 7 of Set 10 | gouyave
# Processing Record 8 of Set 10 | sistranda
# Processing Record 9 of Set 10 | husavik
# Processing Record 10 of Set 10 | norrtalje
# Processing Record 11 of Set 10 | alpena
# Processing Record 12 of Set 10 | minab
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | superior
# Processing Record 17 of Set 10 | sinnamary
# Processing Record 18 of Set 10 | egvekinot
# Processing Record 19 of Set 10 | haysyn
# Processing Record 20 of Set 10 | palmer
# Processing Record 21 of Set 10 | baijiantan
# Processing Record 22 of Set 10 | beirut
# Processing Record 23 of Set 10 | mitsamiouli
# Processing Record 24 of Set 10 | wilmington
# Processing Record 25 of Set 10 | san joaquin
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | pitea
# Processing Record 28 of Set 10 | ilulissat
# Processing Record 29 of Set 10 | kamenka
# Processing Record 30 of Set 10 | biskamzha
# Processing Record 31 of Set 10 | lappeenranta
# Processing Record 32 of Set 10 | paris
# Processing Record 33 of Set 10 | ostrovnoy
# Processing Record 34 of Set 10 | rafaela
# Processing Record 35 of Set 10 | lethem
# Processing Record 36 of Set 10 | pangody
# Processing Record 37 of Set 10 | ayios kirikos
# City not found. Skipping...
# Processing Record 38 of Set 10 | esperance
# Processing Record 39 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 40 of Set 10 | sorland
# Processing Record 41 of Set 10 | namibe
# Processing Record 42 of Set 10 | the pas
# Processing Record 43 of Set 10 | port hawkesbury
# Processing Record 44 of Set 10 | laredo
# Processing Record 45 of Set 10 | middelburg
# Processing Record 46 of Set 10 | villarrica
# Processing Record 47 of Set 10 | colares
# Processing Record 48 of Set 10 | awbari
# Processing Record 49 of Set 10 | vila
# Processing Record 50 of Set 10 | ust-tsilma
# Processing Record 1 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 11 | antalya
# Processing Record 3 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 11 | havre-saint-pierre
# Processing Record 5 of Set 11 | magadi
# Processing Record 6 of Set 11 | ortakoy
# Processing Record 7 of Set 11 | namatanai
# Processing Record 8 of Set 11 | porto velho
# Processing Record 9 of Set 11 | hay river
# Processing Record 10 of Set 11 | enshi
# Processing Record 11 of Set 11 | coquimbo
# Processing Record 12 of Set 11 | bud
# Processing Record 13 of Set 11 | leshukonskoye
# Processing Record 14 of Set 11 | ploemeur
# Processing Record 15 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 11 | merced
# Processing Record 17 of Set 11 | missungwi
# Processing Record 18 of Set 11 | lavrentiya
# Processing Record 19 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 11 | thunder bay
# Processing Record 21 of Set 11 | kamaishi
# Processing Record 22 of Set 11 | okhotsk
# Processing Record 23 of Set 11 | ocumare del tuy
# Processing Record 24 of Set 11 | caravelas
# Processing Record 25 of Set 11 | comodoro rivadavia
# Processing Record 26 of Set 11 | dafeng
# Processing Record 27 of Set 11 | kiama
# Processing Record 28 of Set 11 | do rud
# City not found. Skipping...
# Processing Record 29 of Set 11 | santa vitoria
# Processing Record 30 of Set 11 | saint george
# Processing Record 31 of Set 11 | ulety
# Processing Record 32 of Set 11 | veraval
# Processing Record 33 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 11 | fulitun
# City not found. Skipping...
# Processing Record 35 of Set 11 | warmbad
# Processing Record 36 of Set 11 | kyra
# Processing Record 37 of Set 11 | kutum
# Processing Record 38 of Set 11 | katangli
# Processing Record 39 of Set 11 | gorkovskiy
# Processing Record 40 of Set 11 | ust-nera
# Processing Record 41 of Set 11 | aketi
# Processing Record 42 of Set 11 | taksimo
# Processing Record 43 of Set 11 | axim
# Processing Record 44 of Set 11 | moree
# Processing Record 45 of Set 11 | skjervoy
# Processing Record 46 of Set 11 | jermuk
# Processing Record 47 of Set 11 | nikki
# Processing Record 48 of Set 11 | waipawa
# Processing Record 49 of Set 11 | copiapo
# Processing Record 50 of Set 11 | kavaratti
# Processing Record 1 of Set 12 | nuuk
# Processing Record 2 of Set 12 | kaseda
# Processing Record 3 of Set 12 | sao luis
# Processing Record 4 of Set 12 | keti bandar
# Processing Record 5 of Set 12 | ziro
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | los llanos de aridane
# Processing Record 8 of Set 12 | krasne
# Processing Record 9 of Set 12 | fare
# Processing Record 10 of Set 12 | coihaique
# Processing Record 11 of Set 12 | luanda
# Processing Record 12 of Set 12 | pacific grove
# Processing Record 13 of Set 12 | santarem
# Processing Record 14 of Set 12 | jalu
# Processing Record 15 of Set 12 | camacha
# Processing Record 16 of Set 12 | alcudia
# Processing Record 17 of Set 12 | onega
# Processing Record 18 of Set 12 | matamoros
# Processing Record 19 of Set 12 | quang ngai
# Processing Record 20 of Set 12 | marsa matruh
# Processing Record 21 of Set 12 | vila franca do campo
# Processing Record 22 of Set 12 | kieta
# Processing Record 23 of Set 12 | bay roberts
# Processing Record 24 of Set 12 | tanete
# Processing Record 25 of Set 12 | brae
# Processing Record 26 of Set 12 | malmesbury
# Processing Record 27 of Set 12 | westport
# Processing Record 28 of Set 12 | ambilobe
# Processing Record 29 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 12 | pimentel
# Processing Record 31 of Set 12 | necochea
# Processing Record 32 of Set 12 | bandrele
# Processing Record 33 of Set 12 | dawlatabad
# Processing Record 34 of Set 12 | pervomayskoye
# Processing Record 35 of Set 12 | cockburn town
# Processing Record 36 of Set 12 | yagodnoye
# Processing Record 37 of Set 12 | grigiskes
# Processing Record 38 of Set 12 | berdigestyakh
# Processing Record 39 of Set 12 | myaundzha
# Processing Record 40 of Set 12 | pisco
# Processing Record 41 of Set 12 | mullovka
# Processing Record 42 of Set 12 | itoman
# Processing Record 43 of Set 12 | dryden
# Processing Record 44 of Set 12 | dukat
# Processing Record 45 of Set 12 | paranaiba
# Processing Record 46 of Set 12 | harsum
# Processing Record 47 of Set 12 | lodja
# Processing Record 48 of Set 12 | roma
# Processing Record 49 of Set 12 | yangjiang
# Processing Record 50 of Set 12 | lardos
# Processing Record 1 of Set 13 | presidente medici
# Processing Record 2 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 13 | naspur
# Processing Record 4 of Set 13 | hellvik
# Processing Record 5 of Set 13 | makinsk
# Processing Record 6 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 13 | anakapalle
# Processing Record 8 of Set 13 | talara
# Processing Record 9 of Set 13 | maceio
# Processing Record 10 of Set 13 | bilma
# Processing Record 11 of Set 13 | hokitika
# Processing Record 12 of Set 13 | pachino
# Processing Record 13 of Set 13 | pokhara
# Processing Record 14 of Set 13 | shingu
# Processing Record 15 of Set 13 | gdansk
# Processing Record 16 of Set 13 | mwandiga
# Processing Record 17 of Set 13 | ilinge
# Processing Record 18 of Set 13 | hambantota
# Processing Record 19 of Set 13 | zambezi
# Processing Record 20 of Set 13 | gizo
# Processing Record 21 of Set 13 | kysyl-syr
# Processing Record 22 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 13 | boguchany
# Processing Record 24 of Set 13 | daru
# Processing Record 25 of Set 13 | bhum
# Processing Record 26 of Set 13 | baculin
# Processing Record 27 of Set 13 | denison
# Processing Record 28 of Set 13 | tahe
# Processing Record 29 of Set 13 | chabahar
# Processing Record 30 of Set 13 | kudahuvadhoo
# Processing Record 31 of Set 13 | cienaga de oro
# Processing Record 32 of Set 13 | whitehorse
# Processing Record 33 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 34 of Set 13 | mapimi
# Processing Record 35 of Set 13 | dese
# Processing Record 36 of Set 13 | talen
# Processing Record 37 of Set 13 | mount gambier
# Processing Record 38 of Set 13 | ostersund
# Processing Record 39 of Set 13 | perbaungan
# Processing Record 40 of Set 13 | fillan
# Processing Record 41 of Set 13 | beidao
# Processing Record 42 of Set 13 | chifeng
# Processing Record 43 of Set 13 | shelburne
# Processing Record 44 of Set 13 | kutulik
# Processing Record 45 of Set 13 | baglan
# Processing Record 46 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 13 | hede
# Processing Record 48 of Set 13 | hamilton
# Processing Record 49 of Set 13 | andrews
# Processing Record 50 of Set 13 | kuah
# Processing Record 1 of Set 14 | nishihara
# Processing Record 2 of Set 14 | novikovo
# Processing Record 3 of Set 14 | kimbe
# Processing Record 4 of Set 14 | zeya
# Processing Record 5 of Set 14 | ginir
# Processing Record 6 of Set 14 | marovoay
# Processing Record 7 of Set 14 | santa cruz
# Processing Record 8 of Set 14 | rosarito
# Processing Record 9 of Set 14 | loncoche
# Processing Record 10 of Set 14 | basak
# Processing Record 11 of Set 14 | sept-iles
# Processing Record 12 of Set 14 | takoradi
# Processing Record 13 of Set 14 | nago
# Processing Record 14 of Set 14 | katete
# Processing Record 15 of Set 14 | shimoda
# Processing Record 16 of Set 14 | bayir
# Processing Record 17 of Set 14 | semey
# Processing Record 18 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 14 | sumbe
# Processing Record 20 of Set 14 | lebedinyy
# Processing Record 21 of Set 14 | riohacha
# Processing Record 22 of Set 14 | itamaraca
# Processing Record 23 of Set 14 | lasem
# Processing Record 24 of Set 14 | kankon
# Processing Record 25 of Set 14 | kidal
# Processing Record 26 of Set 14 | kemin
# Processing Record 27 of Set 14 | hirara
# Processing Record 28 of Set 14 | general roca
# Processing Record 29 of Set 14 | lahat
# Processing Record 30 of Set 14 | jishou
# Processing Record 31 of Set 14 | kamina
# Processing Record 32 of Set 14 | port augusta
# Processing Record 33 of Set 14 | caranavi
# Processing Record 34 of Set 14 | wanning
# Processing Record 35 of Set 14 | kyshtovka
# Processing Record 36 of Set 14 | mercedes
# Processing Record 37 of Set 14 | polunochnoye
# Processing Record 38 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 14 | margate
# Processing Record 40 of Set 14 | emba
# Processing Record 41 of Set 14 | beringovskiy
# Processing Record 42 of Set 14 | parkes
# Processing Record 43 of Set 14 | baykit
# Processing Record 44 of Set 14 | ixtapa
# Processing Record 45 of Set 14 | rafraf
# Processing Record 46 of Set 14 | toora-khem
# Processing Record 47 of Set 14 | moron
# Processing Record 48 of Set 14 | andenes
# Processing Record 49 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 14 | adrar
# Processing Record 1 of Set 15 | ayer tawar
# Processing Record 2 of Set 15 | abu dhabi
# Processing Record 3 of Set 15 | san cristobal
# Processing Record 4 of Set 15 | denton
# Processing Record 5 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 15 | araouane
# Processing Record 7 of Set 15 | dentsville
# Processing Record 8 of Set 15 | mizdah
# Processing Record 9 of Set 15 | barcelos
# Processing Record 10 of Set 15 | klyuchi
# Processing Record 11 of Set 15 | fort nelson
# Processing Record 12 of Set 15 | brunswick
# Processing Record 13 of Set 15 | serenje
# Processing Record 14 of Set 15 | christchurch
# Processing Record 15 of Set 15 | katubao
# Processing Record 16 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 17 of Set 15 | honningsvag
# Processing Record 18 of Set 15 | severomuysk
# Processing Record 19 of Set 15 | otane
# Processing Record 20 of Set 15 | novyy urengoy
# Processing Record 21 of Set 15 | sai buri
# Processing Record 22 of Set 15 | acapulco
# Processing Record 23 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 15 | santa maria del oro
# Processing Record 25 of Set 15 | castlerea
# Processing Record 26 of Set 15 | erdenet
# Processing Record 27 of Set 15 | corn island
# Processing Record 28 of Set 15 | takaka
# Processing Record 29 of Set 15 | hobyo
# Processing Record 30 of Set 15 | pontes e lacerda
# Processing Record 31 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 15 | lotung
# City not found. Skipping...
# Processing Record 33 of Set 15 | peachland
# Processing Record 34 of Set 15 | asau
# Processing Record 35 of Set 15 | arnold
# Processing Record 36 of Set 15 | peleduy
# Processing Record 37 of Set 15 | pallasovka
# Processing Record 38 of Set 15 | mayumba
# Processing Record 39 of Set 15 | goderich
# Processing Record 40 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 15 | san quintin
# Processing Record 42 of Set 15 | berlevag
# Processing Record 43 of Set 15 | ossora
# Processing Record 44 of Set 15 | shache
# Processing Record 45 of Set 15 | yenagoa
# Processing Record 46 of Set 15 | sur
# Processing Record 47 of Set 15 | russellville
# Processing Record 48 of Set 15 | uaua
# Processing Record 49 of Set 15 | santa cruz del sur
# Processing Record 50 of Set 15 | barra dos coqueiros
# Processing Record 1 of Set 16 | saint-georges
# Processing Record 2 of Set 16 | linhares
# Processing Record 3 of Set 16 | boralday
# Processing Record 4 of Set 16 | ahuimanu
# Processing Record 5 of Set 16 | san carlos de bariloche
# Processing Record 6 of Set 16 | port blair
# Processing Record 7 of Set 16 | mount pleasant
# Processing Record 8 of Set 16 | tshikapa
# Processing Record 9 of Set 16 | naantali
# Processing Record 10 of Set 16 | atkarsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tuktoyaktuk      CA  69.4541 -133.0374     26.60       100          75
# 1       Ulladulla      AU -35.3500  150.4667     62.10        71         100
# 2      Arenapolis      BR -14.4503  -56.8461     79.02        75          90
# 3       Mahebourg      MU -20.4081   57.7000     71.26        94          40
# 4  Severo-Kurilsk      RU  50.6789  156.1250     48.11        69          21
# 5          Gumdag      TM  39.2061   54.5906     56.23        25           1
# 6       Abu Zabad      SD  12.3500   29.2500     73.31        88         100
# 7        Lorengau      PG  -2.0226  147.2712     85.69        72          16
# 8          Klaeng      TH  12.7797  101.6483     83.16       100         100
# 9          Hegang      CN  47.4000  130.3667     54.09        49          95
#
#    Wind Speed Current Description
# 0       11.50       broken clouds
# 1        5.19     overcast clouds
# 2        1.97     overcast clouds
# 3        3.44    scattered clouds
# 4       17.49          few clouds
# 5       20.15           clear sky
# 6       10.20       moderate rain
# 7        8.05          few clouds
# 8       10.36     overcast clouds
# 9        7.25     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
